# %% [markdown]
# <div style="background-color: #01377D; padding: 10px; text-align: center; color: white; font-size: 32px; font-family: 'Arial', sans-serif;">
#     Assignment 2 Visualized the CSV file <br><br>
#
# </div>

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load the csv file

# %%
df=pd.read_csv("final_dataset.csv")

# %%
df
# Out:
#       Date  Month  Year  Holidays_Count  Days   PM2.5    PM10     NO2    SO2  \
# 0        1      1  2021               0     5  408.80  442.42  160.61  12.95
# 1        2      1  2021               0     6  404.04  561.95   52.85   5.18
# 2        3      1  2021               1     7  225.07  239.04  170.95  10.93
# 3        4      1  2021               0     1   89.55  132.08  153.98  10.42
# 4        5      1  2021               0     2   54.06   55.54  122.66   9.70
# ...    ...    ...   ...             ...   ...     ...     ...     ...    ...
# 1456    27     12  2024               0     5   58.43  249.17   41.69  65.89
# 1457    28     12  2024               0     6   33.83  150.77   33.31  66.14
# 1458    29     12  2024               1     7   31.21  139.75   27.01  65.94
# 1459    30     12  2024               0     1   38.01  152.83   29.12  65.16
# 1460    31     12  2024               0     2   80.42  318.96   40.37  64.98
#
#         CO  Ozone  AQI
# ...

# %% [markdown]
# ## Perform the visualization

# %%
df.head()
# Out:
#    Date  Month  Year  Holidays_Count  Days   PM2.5    PM10     NO2    SO2  \
# 0     1      1  2021               0     5  408.80  442.42  160.61  12.95
# 1     2      1  2021               0     6  404.04  561.95   52.85   5.18
# 2     3      1  2021               1     7  225.07  239.04  170.95  10.93
# 3     4      1  2021               0     1   89.55  132.08  153.98  10.42
# 4     5      1  2021               0     2   54.06   55.54  122.66   9.70
#
#      CO  Ozone  AQI
# 0  2.77  43.19  462
# 1  2.60  16.43  482
# 2  1.40  44.29  263
# 3  1.01  49.19  207
# 4  0.64  48.88  149

# %%
df.tail()
# Out:
#       Date  Month  Year  Holidays_Count  Days  PM2.5    PM10    NO2    SO2  \
# 1456    27     12  2024               0     5  58.43  249.17  41.69  65.89
# 1457    28     12  2024               0     6  33.83  150.77  33.31  66.14
# 1458    29     12  2024               1     7  31.21  139.75  27.01  65.94
# 1459    30     12  2024               0     1  38.01  152.83  29.12  65.16
# 1460    31     12  2024               0     2  80.42  318.96  40.37  64.98
#
#         CO  Ozone  AQI
# 1456  0.99  36.25  263
# 1457  0.79  35.19  113
# 1458  0.57  35.88  142
# 1459  0.55  38.38  116
# 1460  0.84  39.93  209

# %%
df.shape
# Out:
# (1461, 12)

# %%
df.iloc[22:34]
# Out:
#     Date  Month  Year  Holidays_Count  Days   PM2.5    PM10     NO2   SO2  \
# 22    23      1  2021               0     6  170.36  213.65  143.41  4.06
# 23    24      1  2021               1     7  230.38  287.86  123.99  3.05
# 24    25      1  2021               0     1  186.34  311.67   17.33  6.28
# 25    26      1  2021               1     2  207.46  344.53   21.93  9.03
# 26    27      1  2021               0     3  216.71  397.43   34.50  7.94
# 27    28      1  2021               0     4  294.71  496.55   40.31  9.89
# 28    29      1  2021               0     5  301.61  396.57  118.81  4.94
# 29    30      1  2021               0     6  209.05  306.17   99.31  4.76
# 30    31      1  2021               1     7  222.87  323.33  123.23  4.43
# 31     1      2  2021               0     1  285.13  398.91  117.62  4.76
# 32     2      2  2021               0     2  304.79  416.62  127.92  6.06
# 33     3      2  2021               0     3  209.32  299.00  159.84  3.83
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 0 to 1460
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            1461 non-null   int64
#  1   Month           1461 non-null   int64
#  2   Year            1461 non-null   int64
#  3   Holidays_Count  1461 non-null   int64
#  4   Days            1461 non-null   int64
#  5   PM2.5           1461 non-null   float64
#  6   PM10            1461 non-null   float64
#  7   NO2             1461 non-null   float64
#  8   SO2             1461 non-null   float64
#  9   CO              1461 non-null   float64
#  10  Ozone           1461 non-null   float64
#  11  AQI             1461 non-null   int64
# dtypes: float64(6), int64(6)
# memory usage: 137.1 KB

# %%
df.describe()
# Out:
#               Date        Month         Year  Holidays_Count         Days  \
# count  1461.000000  1461.000000  1461.000000     1461.000000  1461.000000
# mean     15.729637     6.522930  2022.501027        0.189596     4.000684
# std       8.803105     3.449884     1.118723        0.392116     2.001883
# min       1.000000     1.000000  2021.000000        0.000000     1.000000
# 25%       8.000000     4.000000  2022.000000        0.000000     2.000000
# 50%      16.000000     7.000000  2023.000000        0.000000     4.000000
# 75%      23.000000    10.000000  2024.000000        0.000000     6.000000
# max      31.000000    12.000000  2024.000000        1.000000     7.000000
#
#              PM2.5         PM10          NO2          SO2           CO  \
# count  1461.000000  1461.000000  1461.000000  1461.000000  1461.000000
# mean     90.774538   218.219261    37.184921    20.104921     1.025832
# std      71.650579   129.297734    35.225327    16.543659     0.608305
# ...

# %%
df.sample()
# Out:
#      Date  Month  Year  Holidays_Count  Days   PM2.5    PM10   NO2    SO2  \
# 118    29      4  2021               0     4  215.39  406.98  58.3  25.24
#
#        CO  Ozone  AQI
# 118  2.21  60.72  303

# %%
df.columns
# Out:
# Index(['Date', 'Month', 'Year', 'Holidays_Count', 'Days', 'PM2.5', 'PM10',
#        'NO2', 'SO2', 'CO', 'Ozone', 'AQI'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Date              0
# Month             0
# Year              0
# Holidays_Count    0
# Days              0
# PM2.5             0
# PM10              0
# NO2               0
# SO2               0
# CO                0
# Ozone             0
# AQI               0
# dtype: int64

# %%
df.dropna()
# Out:
#       Date  Month  Year  Holidays_Count  Days   PM2.5    PM10     NO2    SO2  \
# 0        1      1  2021               0     5  408.80  442.42  160.61  12.95
# 1        2      1  2021               0     6  404.04  561.95   52.85   5.18
# 2        3      1  2021               1     7  225.07  239.04  170.95  10.93
# 3        4      1  2021               0     1   89.55  132.08  153.98  10.42
# 4        5      1  2021               0     2   54.06   55.54  122.66   9.70
# ...    ...    ...   ...             ...   ...     ...     ...     ...    ...
# 1456    27     12  2024               0     5   58.43  249.17   41.69  65.89
# 1457    28     12  2024               0     6   33.83  150.77   33.31  66.14
# 1458    29     12  2024               1     7   31.21  139.75   27.01  65.94
# 1459    30     12  2024               0     1   38.01  152.83   29.12  65.16
# 1460    31     12  2024               0     2   80.42  318.96   40.37  64.98
#
#         CO  Ozone  AQI
# ...

# %%
#check single missing value

df['Holidays_Count'].isnull().sum()
# Out:
# np.int64(0)

# %%
#check multiple missing value

#check dupicated row in dataset 
df[['Days','Ozone','AQI']].isnull().sum()
# Out:
# Days     0
# Ozone    0
# AQI      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#drop(delete) missing value row
df_listwise_deletion=df.dropna()

# %%
df
# Out:
#       Date  Month  Year  Holidays_Count  Days   PM2.5    PM10     NO2    SO2  \
# 0        1      1  2021               0     5  408.80  442.42  160.61  12.95
# 1        2      1  2021               0     6  404.04  561.95   52.85   5.18
# 2        3      1  2021               1     7  225.07  239.04  170.95  10.93
# 3        4      1  2021               0     1   89.55  132.08  153.98  10.42
# 4        5      1  2021               0     2   54.06   55.54  122.66   9.70
# ...    ...    ...   ...             ...   ...     ...     ...     ...    ...
# 1456    27     12  2024               0     5   58.43  249.17   41.69  65.89
# 1457    28     12  2024               0     6   33.83  150.77   33.31  66.14
# 1458    29     12  2024               1     7   31.21  139.75   27.01  65.94
# 1459    30     12  2024               0     1   38.01  152.83   29.12  65.16
# 1460    31     12  2024               0     2   80.42  318.96   40.37  64.98
#
#         CO  Ozone  AQI
# ...

# %% [markdown]
# ## Bar plot

# %%
plt.bar(df["Year"], df["SO2"])
plt.title("Bar plot")
plt.xlabel("Years")
plt.ylabel("Days")
plt.show()

# %%
plt.bar(df["Year"], df["AQI"])
plt.title("Bar plot")
plt.xlabel("Years")
plt.ylabel("Days")
plt.show()

# %%
plt.bar(df["Year"], df["Ozone"])
plt.title("Bar plot")
plt.xlabel("Years")
plt.ylabel("Days")
plt.show()

# %%
plt.bar(df["Year"], df["SO2"])
plt.title("Bar plot")
plt.xlabel("Years")
plt.ylabel("Days")
plt.show()

# %% [markdown]
# ## scatter plotting

# %%
plt.scatter(df["AQI"],df["Ozone"])
plt.title("sample plot")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %%
plt.scatter(df["Year"],df["AQI"])
plt.title("sample plot")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %% [markdown]
# ## histogram plotting

# %%
plt.hist(df["SO2"], bins=15)
plt.title("plotting")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %%
plt.hist(df["AQI"], bins=15)
plt.title("plotting")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %%
plt.hist(df["NO2"], bins=15)
plt.title("plotting")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %%
plt.hist(df["CO"], bins=5)
plt.title("plotting")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %%
plt.hist(df["CO"])
plt.title("plotting")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %%
plt.hist(df["AQI"], bins=15,color='orange',edgecolor='black')
plt.title("plotting")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %%
plt.plot(df["Year"],df["Ozone"], marker='o', linestyle='--',color='red')
plt.title("plotting")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()
