# %% [markdown]
# # Time Series And Fetch Data

# %% [markdown]
# # Section -1

# %%
# install library Yahoo Finance
# !pip install yfinance              # portal - https://finance.yahoo.com/markets/
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import yfinance as yf #fetch stock data from yahoo finance
import pandas as pd # handle and manipulates data 
import matplotlib.pyplot as plt  # plotting graphs

# %%
# Define Stock and Fetch Data

stock = "AAPL"
start_date = '2022-01-01'
end_date = '2023-12-31'

data = yf.download(stock, start=start_date, end=end_date)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_17804\1326156328.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(stock, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed

# %%
data
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2022-01-03  178.645660  179.499589  174.425155  174.542932  104487900
# 2022-01-04  176.378357  179.558473  175.809076  179.254206   99310400
# 2022-01-05  171.686707  176.839663  171.411883  176.290017   94537600
# 2022-01-06  168.820694  172.059699  168.467348  169.507752   96904000
# 2022-01-07  168.987518  170.921105  167.868591  169.694211   86709100
# ...                ...         ...         ...         ...        ...
# 2023-12-22  192.192551  193.989390  191.567126  193.761051   37149600
# 2023-12-26  191.646561  192.480450  191.428159  192.202487   28919300
# 2023-12-27  191.745819  192.093281  189.700797  191.090629   48087700
# 2023-12-28  192.172699  193.244849  191.765676  192.728625   34049900
# 2023-12-29  191.130341  192.986741  190.336153  192.490376   42672100
#
# [501 rows x 5 columns]

# %%
data.describe()
# Out:
# Price        Close        High         Low        Open        Volume
# Ticker        AAPL        AAPL        AAPL        AAPL          AAPL
# count   501.000000  501.000000  501.000000  501.000000  5.010000e+02
# mean    161.620328  163.288978  159.788979  161.460145  7.359559e+07
# std      17.781001   17.512542   18.043880   17.813390  2.536654e+07
# min     123.421257  126.136090  122.582119  124.398597  2.404830e+07
# 25%     147.230194  148.842056  145.348127  146.716202  5.414710e+07
# 50%     162.529877  163.731970  160.200711  162.136728  6.924600e+07
# 75%     174.569946  176.057069  172.656490  174.542932  8.670910e+07
# max     196.669785  198.168802  195.567834  196.580442  1.826020e+08

# %%
data.head()
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2022-01-03  178.645660  179.499589  174.425155  174.542932  104487900
# 2022-01-04  176.378357  179.558473  175.809076  179.254206   99310400
# 2022-01-05  171.686707  176.839663  171.411883  176.290017   94537600
# 2022-01-06  168.820694  172.059699  168.467348  169.507752   96904000
# 2022-01-07  168.987518  170.921105  167.868591  169.694211   86709100

# %%
data.tail()
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker            AAPL        AAPL        AAPL        AAPL      AAPL
# Date
# 2023-12-22  192.192551  193.989390  191.567126  193.761051  37149600
# 2023-12-26  191.646561  192.480450  191.428159  192.202487  28919300
# 2023-12-27  191.745819  192.093281  189.700797  191.090629  48087700
# 2023-12-28  192.172699  193.244849  191.765676  192.728625  34049900
# 2023-12-29  191.130341  192.986741  190.336153  192.490376  42672100

# %%
data.sample(5)
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker            AAPL        AAPL        AAPL        AAPL      AAPL
# Date
# 2023-04-18  164.592102  165.521501  163.781345  164.226281  49923000
# 2023-09-14  174.232849  174.589762  172.091370  172.507766  60895800
# 2022-08-23  164.818054  166.276719  164.246418  164.670224  54147100
# 2022-12-20  130.608154  131.546003  128.228970  129.709788  77432800
# 2022-06-23  136.086746  136.401686  133.488432  134.659644  72433800

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 501 entries, 2022-01-03 to 2023-12-29
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (Close, AAPL)   501 non-null    float64
#  1   (High, AAPL)    501 non-null    float64
#  2   (Low, AAPL)     501 non-null    float64
#  3   (Open, AAPL)    501 non-null    float64
#  4   (Volume, AAPL)  501 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 23.5 KB

# %%
plt.figure(figsize=(12,6))

# %%
plt.grid()

# %%
plt.grid(True)

# %%
plt.plot(data['Close'], label='Closing Value')

# %%
plt.title(f'{stock}Closing Value over Time')
# Out:
# Text(0.5, 1.0, 'AAPLClosing Value over Time')

# %%
plt.xlabel('Date')
# Out:
# Text(0.5, 0, 'Date')

# %%
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.legend()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_17804\4061938096.py:1: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
plt.ylabel('Price(USD)')
# Out:
# Text(0, 0.5, 'Price(USD)')

# %%
plt.figure(figsize=(12,6))
plt.plot(data['Close'], label='Closing value')
plt.title(f'{stock} Closing Price Over Time')
plt.xlabel('Date')
plt.ylabel('Price(USD)')
plt.legend()
plt.grid(True)
plt.show()
